# %%
import os
import argparse
import sys
import platform
import time
import configparser as ConfigParser
from shutil import copyfile
from config.settings import *
import pandas as pd
from images import *
# metrics
import torch
from torchmetrics import ConfusionMatrix
from torchmetrics.functional import dice_score
from torchmetrics.functional import f1

# %% [markdown]
# # Evaluate predict, target

# %%
# Training settings
st = Settings()
options = st.get_options()

# set task to train
options['task'] = 'training'
if options['task'] =='training':
    folder = 'train_folder'
else: folder = 'test_folder'
# list scan
fold = 0
# fold train data
df = pd.read_csv(options['train_csv_path'])
# select training scans
train_files = df.loc[df['fold'] != fold, ['patient_id','study']].values
valid_files = df.loc[df['fold'] == fold, ['patient_id', 'study']].values
train_scan_list = [f[0]+f[1] for f in train_files]
valid_scan_list = [f[0]+f[1] for f in valid_files]


valid_scan_list.sort()
train_scan_list.sort()

# %%
#df

# %%
#scan_list = valid_scan_list+train_scan_list
#scan_list = train_scan_list
scan_list = valid_scan_list
scan_list.sort()
scan_list#=scan_list[:3]
# Out:
# ['training01_03',
#  'training02_01',
#  'training03_04',
#  'training04_02',
#  'training05_04']

# %% [markdown]
# # post process segments

# %%
#options['experiment']='resnet_DAN_full_miccai_train2'
#options['experiment'] = 'resnet_DAN_full_isbi_train_dropout_patch16'
#options['pre_trained_model'] = '1_model.pth'
#options['experiment'] = 'resnet_DAN_full_isbi_train_dropout_patch16_3fc_from55model'
options['experiment'] = 'resnet_DAN_full_isbi_train_2dropout_patch16_1fc_frommodel1'

# %%
accuracy_df=pd.DataFrame(columns=['patient_id', 'study', 'dice_score', 'tpr', 'fpr', 'f1'])
confmat = ConfusionMatrix(num_classes=2)

for scan in scan_list:
    d=0.0001
    patient_id,study = scan.split('_')[0],scan.split('_')[1]
    path=os.path.join(options[folder],scan)
    lesion_path = os.path.join(path, 'tmp/lesion.nii.gz')
    predicted_path = os.path.join(path, options['experiment'],options['experiment'] +'_hard_seg.nii.gz')
    #predicted_path = os.path.join(path, options['experiment'],options['experiment'] +'_debug_prob_0.nii.gz')
    
    target=load_img(lesion_path)
    predict=load_img(predicted_path)

    target = torch.from_numpy(target).to(torch.uint8)
    predict = torch.from_numpy(predict).to(torch.uint8)
    
    convm = confmat(predict, target)
    tn, fp, fn, tp = convm.ravel()
    tn, fp, fn, tp =tn.item(), fp.item(), fn.item(), tp.item()
    tpr=(tp+d)/(tp+fn+d)
    fpr=(fp+d)/(fp+tp+d)
    dice = (2 * tp+d) /(2 * tp + fp + fn+d)
    #dice_score(predict, target, bg=True)
    #dice_score(predict, target)
    f1_value = f1(predict, target, num_classes=2,mdmc_average='global').item()

    df = pd.DataFrame([[patient_id, study, dice, tpr, fpr, f1_value ]], columns=['patient_id', 'study', 'dice_score', 'tpr', 'fpr', 'f1'])
    accuracy_df=accuracy_df.append(df)

# %%
# all train data

# %%
accuracy_df
# Out:
#    patient_id study  dice_score       tpr       fpr        f1
# 0  training01    01    0.821909  0.919397  0.256888  0.999022
# 0  training01    02    0.743320  0.991656  0.405546  0.998557
# 0  training01    03    0.718238  0.943790  0.420302  0.998143
# 0  training01    04    0.699128  0.997808  0.461935  0.998016
# 0  training02    01    0.789309  0.953778  0.326780  0.998074
# 0  training02    02    0.885280  0.969368  0.185384  0.998890
# 0  training02    03    0.881006  0.972312  0.194624  0.998836
# 0  training02    04    0.803262  0.999227  0.328442  0.997774
# 0  training03    01    0.593081  0.998831  0.578246  0.998845
# 0  training03    02    0.629519  0.977584  0.535769  0.999148
# 0  training03    03    0.529146  0.998674  0.640074  0.998680
# 0  training03    04    0.524647  0.991113  0.643255  0.998692
# 0  training03    05    0.520127  0.994189  0.647809  0.998623
# 0  training04    01    0.632455  0.909051  0.515088  0.999658
# 0  training04    02    0.422720  0.954007  0.728486  0.999195
# 0  training04    03    0.377907  1.000000  0.767025  0.999097
# 0  training04    04    0.440023  0.993862  0.717437  0.999188
# 0  training05    01    0.418625  0.997460  0.735099  0.998312
# 0  training05    02    0.474458  0.999597  0.688952  0.998456
# 0  training05    03    0.477555  0.998238  0.686150  0.998605
# 0  training05    04    0.449907  0.995893  0.709407  0.998499

# %%
# validation

# %%
#miccai resnet full train train2
accuracy_df
# Out:
#    patient_id study    dice_score           tpr       fpr        f1
# 0  training01    03  1.517066e-01  8.352968e-02  0.174612  0.997658
# 0  training02    01  1.220739e-01  6.544698e-02  0.094184  0.996439
# 0  training03    04  1.931994e-08  1.931994e-08  1.000000  0.999272
# 0  training04    02  5.041270e-01  3.615665e-01  0.167715  0.999780
# 0  training05    04  2.918644e-01  1.964408e-01  0.432432  0.999412

# %%
print('dice_score: ',df["dice_score"].mean())
print('tpr: ',df["tpr"].mean())
print('fpr: ',df["fpr"].mean())
# Out:
# dice_score:  0.291864418781959
# tpr:  0.19644081231027122
# fpr:  0.43243246984624456

# %%
print('dice_score: ',df["dice_score"].mean())
print('tpr: ',df["tpr"].mean())
print('fpr: ',df["fpr"].mean())
# Out:
# dice_score:  0.3038185255198488
# tpr:  0.45836185261236595
# fpr:  0.7727889617733544

# %%
accuracy_df.boxplot(column=['dice_score'])
# Out:
# <AxesSubplot:>

# %%
#isbi resnet full train first network dropout_patch16
accuracy_df
#3.89794
# Out:
#    patient_id study  dice_score       tpr       fpr        f1
# 0  training01    03    0.697275  0.960171  0.452603  0.997909
# 0  training02    01    0.771685  0.984679  0.365551  0.997796
# 0  training03    04    0.466869  0.981453  0.693718  0.998368
# 0  training04    02    0.318502  0.956740  0.808948  0.998735
# 0  training05    04    0.322026  0.996350  0.807951  0.997413

# %%
print('dice_score: ',df["dice_score"].mean())
print('tpr: ',df["tpr"].mean())
print('fpr: ',df["fpr"].mean())
# Out:
# dice_score:  0.32202640173281316
# tpr:  0.9963495323671109
# fpr:  0.8079510980784067

# %%
#isbi resnet full train first network train4
accuracy_df
# Out:
#    patient_id study  dice_score       tpr       fpr        f1
# 0  training01    03    0.714901  0.940648  0.423463  0.998119
# 0  training02    01    0.787373  0.956270  0.330818  0.998046
# 0  training03    04    0.525630  0.989567  0.642144  0.998700
# 0  training04    02    0.437415  0.957195  0.716521  0.999239
# 0  training05    04    0.427837  0.997262  0.727664  0.998356

# %%
print('dice_score: ',df["dice_score"].mean())
print('tpr: ',df["tpr"].mean())
print('fpr: ',df["fpr"].mean())
# Out:
# dice_score:  0.42783732197915136
# tpr:  0.9972621492128679
# fpr:  0.7276635514018691

# %%
#resnet_DAN_full_isbi_train_dropout_patch16_3fc_from55model  second  55,35
accuracy_df
# Out:
#    patient_id study  dice_score       tpr       fpr        f1
# 0  training01    03    0.774798  0.740548  0.187631  0.998921
# 0  training02    01    0.855530  0.907147  0.190530  0.998841
# 0  training03    04    0.798355  0.956530  0.314930  0.999648
# 0  training04    02    0.757243  0.785519  0.269068  0.999844
# 0  training05    04    0.620705  0.962355  0.541920  0.999275

# %%
print('dice_score: ',df["dice_score"].mean())
print('tpr: ',df["tpr"].mean())
print('fpr: ',df["fpr"].mean())
# Out:
# dice_score:  0.6207048810190208
# tpr:  0.9623545525358305
# fpr:  0.5419200744795822

# %%
#resnet_DAN_full_isbi_train_2dropout_patch16_1fc  second  86, 92
accuracy_df
# Out:
#    patient_id study  dice_score       tpr       fpr        f1
# 0  training01    03    0.034451  0.030573  0.960544  0.995703
# 0  training02    01    0.224100  0.169604  0.669804  0.995557
# 0  training03    04    0.063194  0.115920  0.956563  0.997498
# 0  training04    02    0.030983  0.112933  0.982046  0.997818
# 0  training05    04    0.459112  0.953000  0.697604  0.998616

# %%
#resnet_DAN_full_isbi_train_2dropout_patch16_1fc  second  86, 80
accuracy_df
# Out:
#    patient_id study  dice_score       tpr       fpr        f1
# 0  training01    03    0.037615  0.034781  0.959049  0.995537
# 0  training02    01    0.243148  0.190019  0.662483  0.995525
# 0  training03    04    0.062217  0.122102  0.958256  0.997320

# %%
#resnet_DAN_full_isbi_train_2dropout_patch16_1fc  second  86, 80
accuracy_df
# Out:
#    patient_id study  dice_score       tpr       fpr        f1
# 0  training01    03    0.750961  0.833277  0.316555  0.998614
# 0  training02    01    0.809559  0.891232  0.258401  0.998414
# 0  training03    04    0.558867  0.952859  0.604618  0.998905
# 0  training04    02    0.539739  0.903005  0.615101  0.999524
# 0  training05    04    0.429647  0.956879  0.722985  0.998434

# %%
print('dice_score: ',df["dice_score"].mean())
print('tpr: ',df["tpr"].mean())
print('fpr: ',df["fpr"].mean())
# Out:
# dice_score:  0.5588668580234172
# tpr:  0.9528593517608317
# fpr:  0.6046176077872567

# %%
#resnet_DAN_full_isbi_train_dropout_patch16_3fc_from55model  second  55,55
accuracy_df
# Out:
#    patient_id study  dice_score       tpr       fpr        f1
# 0  training01    03    0.797238  0.747952  0.146524  0.999046
# 0  training02    01    0.854648  0.911647  0.195643  0.998827
# 0  training03    04    0.819424  0.950348  0.279795  0.999695
# 0  training04    02    0.762141  0.768215  0.243837  0.999852
# 0  training05    04    0.676174  0.941136  0.472371  0.999444

# %%
#isbi resnet full train second network dropout_patch16   69
accuracy_df
# Out:
#    patient_id study  dice_score       tpr       fpr        f1
# 0  training01    03    0.799746  0.742679  0.133687  0.999067
# 0  training02    01    0.864099  0.889595  0.159978  0.998941
# 0  training03    04    0.739785  0.925232  0.383734  0.999526
# 0  training04    02    0.803063  0.859745  0.246608  0.999870
# 0  training05    04    0.587654  0.976272  0.579666  0.999155

# %%
print('dice_score: ',df["dice_score"].mean())
print('tpr: ',df["tpr"].mean())
print('fpr: ',df["fpr"].mean())
# Out:
# dice_score:  0.5876536456248462
# tpr:  0.9762719603862204
# fpr:  0.5796660159168369

# %%
accuracy_df.boxplot(column=['dice_score'])
# Out:
# <AxesSubplot:>

# %%
#resnet_DAN_full_isbi_train_2dropout_patch16_1fc_frommodel1  second 86,50
accuracy_df
# Out:
#    patient_id study  dice_score       tpr       fpr        f1
# 0  training01    03    0.810836  0.871424  0.241874  0.998980
# 0  training02    01    0.860876  0.928678  0.197700  0.998865
# 0  training03    04    0.648627  0.954019  0.508657  0.999247
# 0  training04    02    0.672137  0.895264  0.461960  0.999730
# 0  training05    04    0.494459  0.982432  0.669633  0.998761

# %%
print('dice_score: ',df["dice_score"].mean())
print('tpr: ',df["tpr"].mean())
print('fpr: ',df["fpr"].mean())
# Out:
# dice_score:  0.4944594390856092
# tpr:  0.9824321245167209
# fpr:  0.6696332693752243

# %%
#resnet_DAN_full_isbi_train_2dropout_patch16_1fc_frommodel1  second 86,90
accuracy_df
# Out:
#    patient_id study  dice_score       tpr       fpr        f1
# 0  training01    03    0.819333  0.856838  0.215027  0.999052
# 0  training02    01    0.862845  0.922059  0.189223  0.998891
# 0  training03    04    0.702846  0.949575  0.442111  0.999415
# 0  training04    02    0.740448  0.895719  0.368945  0.999806
# 0  training05    04    0.543112  0.971481  0.623086  0.998992

# %%
print('dice_score: ',df["dice_score"].mean())
print('tpr: ',df["tpr"].mean())
print('fpr: ',df["fpr"].mean())
# Out:
# dice_score:  0.5431122478117841
# tpr:  0.9714807216180533
# fpr:  0.623085778320919

# %%
#isbi resnet full train second network train4
accuracy_df
# Out:
#    patient_id study  dice_score       tpr       fpr        f1
# 0  training01    03    0.808210  0.777516  0.158572  0.999075
# 0  training02    01    0.834843  0.861929  0.190593  0.998710
# 0  training03    04    0.877500  0.941074  0.178029  0.999809
# 0  training04    02    0.734655  0.877505  0.368197  0.999804
# 0  training05    04    0.799085  0.956423  0.313799  0.999703

# %%
print('dice_score: ',df["dice_score"].mean())
print('tpr: ',df["tpr"].mean())
print('fpr: ',df["fpr"].mean())
# Out:
# dice_score:  0.7990850171559283
# tpr:  0.9564225416381474
# fpr:  0.31379931248976917

# %%
#isbi full train
accuracy_df
# Out:
#    patient_id study  dice_score       tpr       fpr        f1
# 0  training01    03    0.718238  0.943790  0.420302  0.998143
# 0  training02    01    0.789309  0.953778  0.326780  0.998074
# 0  training03    04    0.524647  0.991113  0.643255  0.998692
# 0  training04    02    0.422720  0.954007  0.728486  0.999195
# 0  training05    04    0.449907  0.995893  0.709407  0.998499

# %%
print('dice_score: ',df["dice_score"].mean())
print('tpr: ',df["tpr"].mean())
print('fpr: ',df["fpr"].mean())

# %%
#hard_seg
accuracy_df.boxplot(column=['dice_score'])
# Out:
# <AxesSubplot:>

# %%
#prob_1
accuracy_df
# Out:
#    patient_id study  dice_coefficient  tpr  fpr
# 0  training01    01          0.499024  0.5  0.5
# 0  training01    02          0.534828  0.5  0.5
# 0  training01    03          0.504277  0.5  0.5
# 0  training01    04          0.513522  0.5  0.5
# 0  training02    01          0.572913  0.5  0.5
# 0  training02    02          0.576917  0.5  0.5
# 0  training02    03          0.623156  0.5  0.5
# 0  training02    04          0.643848  0.5  0.5
# 0  training03    01          0.464388  0.5  0.5
# 0  training03    02          0.455096  0.5  0.5
# 0  training03    03          0.466540  0.5  0.5
# 0  training03    04          0.449413  0.5  0.5
# 0  training03    05          0.472756  0.5  0.5
# 0  training04    01          0.399458  0.5  0.5
# 0  training04    02          0.360732  0.5  0.5
# 0  training04    03          0.395806  0.5  0.5
# 0  training04    04          0.377730  0.5  0.5
# 0  training05    01          0.240866  0.5  0.5
# 0  training05    02          0.284804  0.5  0.5
# 0  training05    03          0.312631  0.5  0.5
# 0  training05    04          0.320235  0.5  0.5

# %%
accuracy_df.boxplot(column=['dice_coefficient'])
# Out:
# <AxesSubplot:>

# %%
#threshold = 4
accuracy_df.boxplot(column=['dice_coefficient'])
# Out:
# <AxesSubplot:>
