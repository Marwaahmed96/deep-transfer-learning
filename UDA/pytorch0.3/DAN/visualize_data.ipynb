# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
current_path = os.getcwd()
root_path= '/'.join(current_path.split('/')[:current_path.split('/').index('Code')])
datasets_path=os.path.join(root_path, 'DataSets')

# %%
train_count = 2
dataset_name='ISBI'
experiment_name='resnet_DAN_full_isbi_train_dropout_patch16_3fc_try_last_model'
#experiment_name='resnet_DAN_full_isbi_train_dropout_patch16'
file_name = experiment_name+'_'+str(train_count)+'_history_data.csv'
file_path = os.path.join(datasets_path, dataset_name,'train',file_name)

# %%
train_count = 2
dataset_name='ISBI'
experiment_name='resnet_DAN_full_isbi_train_dropout_patch16_3fc'
#experiment_name='resnet_DAN_full_isbi_train_dropout_patch16'
file_name = experiment_name+'_'+str(train_count)+'_history_data.csv'
file_path = os.path.join(datasets_path, dataset_name,'train',file_name)

# %%
train_count = 2
dataset_name='ISBI'
experiment_name='resnet_DAN_full_isbi_train_dropout_patch16_3fc_from55model'
#experiment_name='resnet_DAN_full_isbi_train_dropout_patch16'
file_name = experiment_name+'_'+str(train_count)+'_history_data.csv'
file_path = os.path.join(datasets_path, dataset_name,'train',file_name)

df = pd.read_csv(file_path)

loss_train = df['loss']
loss_val = df['val_loss']
epochs = range(1,len(loss_train)+1)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy_train = df['accuracy']
accuracy_val = df['val_accuracy']
epochs = range(1,len(accuracy_train)+1)
plt.plot(epochs, accuracy_train, 'g', label='Training accuracy')
plt.plot(epochs, accuracy_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
df
# Out:
#           lr      loss  accuracy  val_loss  val_accuracy
# 0   0.001000  0.434395  0.839739  0.606870      0.748850
# 1   0.000976  0.279505  0.875176  0.812506      0.759181
# 2   0.000953  0.237254  0.894155  0.661873      0.777215
# 3   0.000931  0.205221  0.908774  1.014567      0.777849
# 4   0.000910  0.179687  0.920258  0.946994      0.774350
# 5   0.000891  0.158608  0.929438  1.113086      0.774617
# 6   0.000872  0.143166  0.935704  1.109422      0.760668
# 7   0.000854  0.130927  0.940601  0.901934      0.780348
# 8   0.000838  0.119789  0.945720  1.140258      0.766319
# 9   0.000821  0.109628  0.949876  0.906138      0.782152
# 10  0.000806  0.101416  0.953628  1.023944      0.779128
# 11  0.000791  0.093846  0.956837  0.978124      0.782658
# 12  0.000777  0.086358  0.960228  0.948822      0.786881
# 13  0.000763  0.080117  0.963579  0.922089      0.790232
# 14  0.000750  0.074495  0.965772  1.037769      0.777602
# 15  0.000738  0.069622  0.967963  1.081360      0.784343
# 16  0.000726  0.063284  0.970419  1.007730      0.787823
# 17  0.000714  0.059643  0.972465  1.011702      0.796974
# 18  0.000703  0.055476  0.974458  1.007937      0.797718
# 19  0.000692  0.050931  0.976476  1.056333      0.802923
# 20  0.000682  0.049144  0.977102  1.010102      0.805709
# 21  0.000672  0.045181  0.978691  1.049502      0.802774
# 22  0.000662  0.043303  0.979444  1.064701      0.800276
# 23  0.000653  0.041136  0.980466  1.074708      0.806611
# 24  0.000643  0.037634  0.981870  1.086257      0.806581
# 25  0.000635  0.035621  0.983024  1.077460      0.799701
# 26  0.000626  0.033338  0.983752  1.110691      0.800633
# 27  0.000618  0.031034  0.984616  1.137754      0.799532
# 28  0.000610  0.031425  0.984591  1.109526      0.804935
# 29  0.000602  0.028606  0.985659  1.218848      0.800722
# 30  0.000595  0.027709  0.985881  1.144909      0.803359
# 31  0.000587  0.026261  0.986627  1.212244      0.799859
# 32  0.000580  0.025131  0.987047  1.145792      0.807087
# 33  0.000573  0.023472  0.987738  1.174788      0.808316
# 34  0.000567  0.022430  0.987852  1.212903      0.808336
# 35  0.000560  0.021532  0.988439  1.202419      0.807077
# 36  0.000554  0.020784  0.988713  1.163802      0.811142
# 37  0.000547  0.019983  0.988954  1.224347      0.802625
# 38  0.000541  0.019575  0.989164  1.178411      0.810140
# 39  0.000535  0.018526  0.989596  1.208236      0.811033
# 40  0.000530  0.018353  0.989488  1.172582      0.811251
# 41  0.000524  0.017732  0.989880  1.162422      0.813323
# 42  0.000519  0.016796  0.990315  1.229276      0.813819
# 43  0.000513  0.015847  0.990676  1.203092      0.808177

# %%
train_count = 2
dataset_name='ISBI'
experiment_name='resnet_DAN_full_isbi_train_2dropout_patch16_1fc_frommodel1'
#experiment_name='resnet_DAN_full_isbi_train_dropout_patch16'
file_name = experiment_name+'_'+str(train_count)+'_history_data.csv'
file_path = os.path.join(datasets_path, dataset_name,'train',file_name)

df = pd.read_csv(file_path)

loss_train = df['loss']
loss_val = df['val_loss']
epochs = range(1,len(loss_train)+1)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy_train = df['accuracy']
accuracy_val = df['val_accuracy']
epochs = range(1,len(accuracy_train)+1)
plt.plot(epochs, accuracy_train, 'g', label='Training accuracy')
plt.plot(epochs, accuracy_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
df[-20:]
# Out:
#           lr      loss  accuracy  val_loss  val_accuracy
# 70  0.000405  0.264337  0.881717  0.492714      0.787112
# 71  0.000402  0.263078  0.882056  0.480158      0.788828
# 72  0.000399  0.261054  0.882935  0.481991      0.791677
# 73  0.000396  0.260053  0.883381  0.485238      0.785600
# 74  0.000394  0.258018  0.884166  0.475401      0.794128
# 75  0.000391  0.255689  0.885855  0.485752      0.793137
# 76  0.000388  0.254308  0.885789  0.497467      0.786816
# 77  0.000385  0.252921  0.886747  0.481624      0.789869
# 78  0.000383  0.251463  0.887567  0.483136      0.793056
# 79  0.000380  0.249829  0.888254  0.490485      0.788399
# 80  0.000377  0.247354  0.889526  0.482526      0.790012
# 81  0.000375  0.246700  0.890339  0.488048      0.787806
# 82  0.000372  0.245691  0.890311  0.489820      0.789910
# 83  0.000370  0.245398  0.890609  0.482787      0.795384
# 84  0.000367  0.242130  0.891658  0.484364      0.792279
# 85  0.000365  0.239916  0.892716  0.476545      0.797192
# 86  0.000363  0.238526  0.893611  0.485331      0.794761
# 87  0.000360  0.237060  0.894192  0.486899      0.795823
# 88  0.000358  0.235687  0.894597  0.486029      0.795078
# 89  0.000356  0.234937  0.895235  0.476710      0.798754

# %%
train_count = 2
dataset_name='ISBI'
experiment_name='resnet_DAN_full_isbi_train_2dropout_patch16_1fc'
#experiment_name='resnet_DAN_full_isbi_train_dropout_patch16'
file_name = experiment_name+'_'+str(train_count)+'_history_data.csv'
file_path = os.path.join(datasets_path, dataset_name,'train',file_name)

df = pd.read_csv(file_path)

loss_train = df['loss']
loss_val = df['val_loss']
epochs = range(1,len(loss_train)+1)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy_train = df['accuracy']
accuracy_val = df['val_accuracy']
epochs = range(1,len(accuracy_train)+1)
plt.plot(epochs, accuracy_train, 'g', label='Training accuracy')
plt.plot(epochs, accuracy_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
df[-20:]
# Out:
#            lr      loss  accuracy  val_loss  val_accuracy
# 180  0.000232  0.278976  0.875531  0.534381      0.760641
# 181  0.000232  0.386239  0.821082  0.556544      0.738474
# 182  0.000231  0.327304  0.851614  0.544068      0.754897
# 183  0.000230  0.307517  0.861371  0.533215      0.760324
# 184  0.000229  0.299575  0.866049  0.534361      0.762758
# 185  0.000228  0.292030  0.868524  0.527984      0.765510
# 186  0.000228  0.289015  0.871002  0.531869      0.763393
# 187  0.000227  0.286049  0.873672  0.509591      0.770955
# 188  0.000226  0.296773  0.868835  0.527495      0.768242
# 189  0.000225  0.283593  0.874191  0.522800      0.768608
# 190  0.000224  0.282461  0.874899  0.535565      0.765625
# 191  0.000224  0.280390  0.874921  0.525965      0.769435
# 192  0.000223  0.277041  0.876691  0.527206      0.769579
# 193  0.000222  0.273678  0.878836  0.529776      0.768569
# 194  0.000221  0.272182  0.878491  0.532778      0.765962
# 195  0.000221  0.281841  0.874292  0.524980      0.769502
# 196  0.000220  0.271910  0.879547  0.534676      0.766645
# 197  0.000219  0.268610  0.880823  0.520287      0.772658
# 198  0.000218  0.302595  0.864066  0.639172      0.656625
# 199  0.000218  0.359128  0.834384  0.560656      0.744910

# %%
train_count = 2
dataset_name='ISBI'
experiment_name='resnet_DAN_full_isbi_train_patch16_1fc_withputdrp'
#experiment_name='resnet_DAN_full_isbi_train_dropout_patch16'
file_name = experiment_name+'_'+str(train_count)+'_history_data.csv'
file_path = os.path.join(datasets_path, dataset_name,'train',file_name)

df = pd.read_csv(file_path)

loss_train = df['loss']
loss_val = df['val_loss']
epochs = range(1,len(loss_train)+1)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy_train = df['accuracy']
accuracy_val = df['val_accuracy']
epochs = range(1,len(accuracy_train)+1)
plt.plot(epochs, accuracy_train, 'g', label='Training accuracy')
plt.plot(epochs, accuracy_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
train_count = 1
dataset_name='ISBI'
experiment_name1='resnet_DAN_full_isbi_train_2dropout_patch16_1fc'
experiment_name2='resnet_DAN_full_isbi_train_3dropout_patch16_1fc'
#experiment_name='resnet_DAN_full_isbi_train_dropout_patch16'
file_name1 = experiment_name1+'_'+str(train_count)+'_history_data.csv'
file_name2 = experiment_name2+'_'+str(train_count)+'_history_data.csv'
file_path1 = os.path.join(datasets_path, dataset_name,'train',file_name1)
file_path2 = os.path.join(datasets_path, dataset_name,'train',file_name2)

df1 = pd.read_csv(file_path1)
df2 = pd.read_csv(file_path2)

# %%
len(df1), len(df2)
# Out:
# (119, 161)

# %%
df2 = df2[:119]
len(df1), len(df2)
# Out:
# (119, 119)

# %%
loss_train1 = df1['loss']
loss_train2 = df2['loss']
loss_val1 = df1['val_loss']
loss_val2 = df2['val_loss']
epochs = range(1,len(loss_train1)+1)

plt.plot(epochs, loss_val1, 'g', label='validation loss1')
plt.plot(epochs, loss_val2, 'b', label='validation loss2')
plt.title('Validation loss for training with 2dropout ans 3 dropout layers')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy_val1 = df1['val_accuracy']
accuracy_val2 = df2['val_accuracy']
epochs = range(1,len(accuracy_val1)+1)
plt.plot(epochs, accuracy_val1, 'g', label='validation accuracy1')
plt.plot(epochs, accuracy_val2, 'b', label='validation accuracy2')
plt.title('Validation accuracy for training with 2dropout ans 3 dropout layers')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
train_count = 1
dataset_name='ISBI'
experiment_name='resnet_DAN_full_isbi_train_3dropout_patch16_1fc'
#experiment_name='resnet_DAN_full_isbi_train_dropout_patch16'
file_name = experiment_name+'_'+str(train_count)+'_history_data.csv'
file_path = os.path.join(datasets_path, dataset_name,'train',file_name)

df = pd.read_csv(file_path)

loss_train = df['loss']
loss_val = df['val_loss']
epochs = range(1,len(loss_train)+1)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy_train = df['accuracy']
accuracy_val = df['val_accuracy']
epochs = range(1,len(accuracy_train)+1)
plt.plot(epochs, accuracy_train, 'g', label='Training accuracy')
plt.plot(epochs, accuracy_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
df[-10:]
# Out:
#          lr      loss  accuracy  val_loss  val_accuracy
# 0  0.001000  0.682329  0.712059  2.254643      0.511378
# 1  0.000976  0.357025  0.850409  1.307722      0.615843
# 2  0.000953  0.276457  0.892543  0.697246      0.752123
# 3  0.000931  0.226933  0.914832  0.433605      0.829638
# 4  0.000910  0.184822  0.933760  0.289955      0.883671
# 5  0.000891  0.158670  0.943448  0.223353      0.914266
# 6  0.000872  0.145153  0.948596  0.168241      0.933669

# %%
loss_train = df['loss']
loss_val = df['val_loss']
epochs = range(1,len(loss_train)+1)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
accuracy_train = df['accuracy']
accuracy_val = df['val_accuracy']
epochs = range(1,len(accuracy_train)+1)
plt.plot(epochs, accuracy_train, 'g', label='Training accuracy')
plt.plot(epochs, accuracy_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
train_count = 1
dataset_name='miccai'
experiment_name='resnet_DAN_full_miccai_train_dropout_patch16'
file_name = experiment_name+'_'+str(train_count)+'_history_data.csv'
file_path = os.path.join(datasets_path, dataset_name,'train',file_name)

df = pd.read_csv(file_path)

loss_train = df['loss']
loss_val = df['val_loss']
epochs = range(1,len(loss_train)+1)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy_train = df['accuracy']
accuracy_val = df['val_accuracy']
epochs = range(1,len(accuracy_train)+1)
plt.plot(epochs, accuracy_train, 'g', label='Training accuracy')
plt.plot(epochs, accuracy_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
df.columns
# Out:
# Index(['lr', 'loss', 'accuracy', 'val_loss', 'val_accuracy'], dtype='object')

# %%
loss_train = df['loss']
loss_val = df['val_loss']
epochs = range(1,len(loss_train)+1)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
accuracy_train = df['accuracy']
accuracy_val = df['val_accuracy']
epochs = range(1,len(accuracy_train)+1)
plt.plot(epochs, accuracy_train, 'g', label='Training accuracy')
plt.plot(epochs, accuracy_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
df[:-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Marwa/Environments/deep_transfer_learning_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/Marwa/Environments/deep_transfer_learning_env/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/Marwa/Environments/deep_transfer_learning_env/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_19673/2029431133.py in <module>
# ----> 1 df[-1]
#
# ~/Marwa/Environments/deep_transfer_learning_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/Marwa/Environments/deep_transfer_learning_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: -1

# %%
df
# Out:
#        lr      loss  accuracy  val_loss  val_accuracy
# 0   0.001  0.539806  0.714425  2.015365      0.497133
# 1   0.001  0.307206  0.885267  2.288845      0.497133
# 2   0.001  0.246132  0.911739  2.588118      0.497133
# 3   0.001  0.422911  0.820066  2.903878      0.497133
# 4   0.001  0.689823  0.704872  1.924549      0.522606
# 5   0.001  0.369210  0.844335  1.334243      0.634104
# 6   0.001  0.270130  0.894783  0.597323      0.783763
# 7   0.001  0.210003  0.922280  0.382016      0.858534
# 8   0.001  0.171461  0.938340  0.220220      0.914275
# 9   0.001  0.150770  0.946302  0.206779      0.922831
# 10  0.001  0.140349  0.950630  0.186321      0.929466
# 11  0.001  0.128273  0.954952  0.146699      0.945268
# 12  0.001  0.119553  0.957785  0.131220      0.950780
# 13  0.001  0.116059  0.959180  0.146935      0.946082
# 14  0.001  0.112179  0.960082  0.116653      0.956310
# 15  0.001  0.104936  0.962418  0.110476      0.959106
# 16  0.001  0.102280  0.963518  0.102389      0.961344
# 17  0.001  0.098563  0.964903  0.104894      0.961106
# 18  0.001  0.099412  0.964455  0.100705      0.962203
# 19  0.001  0.094386  0.965858  0.097564      0.962946
# 20  0.001  0.091875  0.966794  0.096578      0.964326
# 21  0.001  0.090675  0.967524  0.092380      0.965636
# 22  0.001  0.088567  0.967988  0.096124      0.964008
# 23  0.001  0.086908  0.968576  0.094065      0.964689
# 24  0.001  0.084362  0.969059  0.093705      0.965167
# 25  0.001  0.082853  0.969976  0.090646      0.966096
# 26  0.001  0.082605  0.969893  0.089917      0.966706
# 27  0.001  0.080633  0.970537  0.090031      0.966671
# 28  0.001  0.079953  0.970786  0.096275      0.964406
# 29  0.001  0.078682  0.971157  0.091630      0.966777
# 30  0.001  0.076467  0.971913  0.090328      0.966591
# 31  0.001  0.076390  0.971940  0.090192      0.966919
# 32  0.001  0.074643  0.972468  0.090453      0.966786
# 33  0.001  0.074348  0.972530  0.092399      0.966228
# 34  0.001  0.073071  0.972927  0.089521      0.967396
# 35  0.001  0.071563  0.973407  0.090109      0.967317
# 36  0.001  0.070981  0.973713  0.086341      0.968352
# 37  0.001  0.070414  0.973853  0.086692      0.968140
# 38  0.001  0.070011  0.973681  0.088618      0.967874
# 39  0.001  0.068858  0.974156  0.087815      0.968078
# 40  0.001  0.068203  0.974693  0.086214      0.968237
# 41  0.001  0.066864  0.974886  0.085422      0.968626
# 42  0.001  0.066185  0.974996  0.086280      0.968856
# 43  0.001  0.065799  0.975267  0.086566      0.968697
# 44  0.001  0.065276  0.975492  0.091051      0.967281
# 45  0.001  0.064313  0.975723  0.084286      0.969122
# 46  0.001  0.063385  0.975983  0.087085      0.968555
# 47  0.001  0.063071  0.976047  0.087940      0.968201
# 48  0.001  0.062485  0.976538  0.089489      0.967724
# 49  0.001  0.062064  0.976393  0.089542      0.967989
# 50  0.001  0.061722  0.976694  0.085599      0.968909

# %%
import torch
train_count = 1
experiment_name='resnet_DAN_full_isbi_train_dropout_patch16_3fc2'
path = os.path.join('./weights', experiment_name, str(train_count),'1_model.pth')

# %%
model=torch.load(path)

# %%
model
# Out:
# DANNet(
#   (sharedNet): ResNet(
#     (conv1): Conv3d(2, 64, kernel_size=(5, 5, 5), stride=(2, 2, 2), padding=(3, 3, 3), bias=False)
#     (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool3d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv3d(64, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (1): Bottleneck(
#         (conv1): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (2): Bottleneck(
#         (conv1): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv3d(256, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#           (1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (1): Bottleneck(
#         (conv1): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (2): Bottleneck(
#         (conv1): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (3): Bottleneck(
#         (conv1): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#           (1): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (1): Bottleneck(
#         (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (2): Bottleneck(
#         (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (3): Bottleneck(
#         (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (4): Bottleneck(
#         (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (5): Bottleneck(
#         (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv3d(1024, 2048, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#           (1): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (1): Bottleneck(
#         (conv1): Conv3d(2048, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (2): Bottleneck(
#         (conv1): Conv3d(2048, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#     )
#     (avgpool): AvgPool3d(kernel_size=1, stride=1, padding=0)
#   )
#   (cls_fc): Linear(in_features=2048, out_features=2, bias=True)
# )

# %%
model
# Out:
# DANNet(
#   (sharedNet): ResNet(
#     (conv1): Conv3d(2, 64, kernel_size=(5, 5, 5), stride=(2, 2, 2), padding=(3, 3, 3), bias=False)
#     (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool3d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv3d(64, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (1): Bottleneck(
#         (conv1): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (2): Bottleneck(
#         (conv1): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv3d(256, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#           (1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (1): Bottleneck(
#         (conv1): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (2): Bottleneck(
#         (conv1): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (3): Bottleneck(
#         (conv1): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#           (1): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (1): Bottleneck(
#         (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (2): Bottleneck(
#         (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (3): Bottleneck(
#         (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (4): Bottleneck(
#         (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (5): Bottleneck(
#         (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv3d(1024, 2048, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#           (1): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (1): Bottleneck(
#         (conv1): Conv3d(2048, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#       (2): Bottleneck(
#         (conv1): Conv3d(2048, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (dropout): Dropout3d(p=0.5, inplace=False)
#       )
#     )
#     (avgpool): AvgPool3d(kernel_size=1, stride=1, padding=0)
#   )
#   (cls_fc): Linear(in_features=2048, out_features=2, bias=True)
# )
